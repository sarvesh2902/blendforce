# %%
import pandas as pd

# %%
employees = pd.read_csv("employee_data.csv")

# %%
employees.head()
# Out:
#    Id      Name   Surname   Division Manager       Gender Sexual_Orientation  \
# 0   1   Deborah   Addison         IT      No  Transgender       Heterosexual
# 1   2      Mona      Hill  Marketing      No         Male       Heterosexual
# 2   3  Kimberly   Shelton    Finance      No       Female       Heterosexual
# 3   4     Denis  Robinson         HR      No         Male       Heterosexual
# 4   5    Carmen      Gunn         RD      No         Male       Heterosexual
#
#                LGBTQ Indigenous Ethnicity  ... Veteran Date of Birth Age  \
# 0  Prefer not to say         No     White  ...      No    1993-06-04  29
# 1                 No        Yes     White  ...      No    1963-08-02  59
# 2                 No         No     White  ...      No    1979-04-25  43
# 3                 No         No     White  ...      No    1978-02-11  44
# 4                 No         No     Asian  ...      No    1972-03-11  50
#
# ...

# %%
selected_columns = employees[['Name', 'Surname', 'Division', 'Gender', 'Ethnicity', 'Sexual_Orientation', 'LGBTQ', 'Indigenous', 'Disability', 'Age' ,'Mobile Number', 'Email']]

# %%
selected_columns.head()
# Out:
#        Name   Surname   Division       Gender Ethnicity Sexual_Orientation  \
# 0   Deborah   Addison         IT  Transgender     White       Heterosexual
# 1      Mona      Hill  Marketing         Male     White       Heterosexual
# 2  Kimberly   Shelton    Finance       Female     White       Heterosexual
# 3     Denis  Robinson         HR         Male     White       Heterosexual
# 4    Carmen      Gunn         RD         Male     Asian       Heterosexual
#
#                LGBTQ Indigenous Disability  Age Mobile Number  \
# 0  Prefer not to say         No        Yes   29  363 436 1096
# 1                 No        Yes         No   59  905 980 9989
# 2                 No         No         No   43  788 356 1577
# 3                 No         No        Yes   44  946 855 5822
# 4                 No         No         No   50  537 895 4532
#
#                       Email
# 0   Deborah.Addison@mail.ca
# 1         Mona.Hill@mail.ca
# 2  Kimberly.Shelton@mail.ca
# ...

# %%
selected_columns['Full Name'] = selected_columns['Name'] + ' ' + selected_columns['Surname']
# Out:
# /var/folders/k0/vtw3mbjn46n83ddlb__pnnvh0000gn/T/ipykernel_3037/2618583185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns['Full Name'] = selected_columns['Name'] + ' ' + selected_columns['Surname']

# %%
selected_columns
# Out:
#           Name    Surname   Division             Gender Ethnicity  \
# 0      Deborah    Addison         IT        Transgender     White
# 1         Mona       Hill  Marketing               Male     White
# 2     Kimberly    Shelton    Finance             Female     White
# 3        Denis   Robinson         HR               Male     White
# 4       Carmen       Gunn         RD               Male     Asian
# ...        ...        ...        ...                ...       ...
# 9995    Louise  Robertson         HR               Male     White
# 9996  Felicity    Gregory      Sales               Male     White
# 9997     Abbey    Randall      Sales               Male     White
# 9998     Benny      Abbot    Finance  Prefer not to say     White
# 9999    Olivia     Denton      Sales             Female     White
#
#      Sexual_Orientation              LGBTQ         Indigenous Disability  Age  \
# 0          Heterosexual  Prefer not to say                 No        Yes   29
# ...

# %%
selected_columns = selected_columns.drop(['Name', 'Surname'], axis=1)

# %%
selected_columns
# Out:
#        Division             Gender Ethnicity Sexual_Orientation  \
# 0            IT        Transgender     White       Heterosexual
# 1     Marketing               Male     White       Heterosexual
# 2       Finance             Female     White       Heterosexual
# 3            HR               Male     White       Heterosexual
# 4            RD               Male     Asian       Heterosexual
# ...         ...                ...       ...                ...
# 9995         HR               Male     White       Heterosexual
# 9996      Sales               Male     White       Heterosexual
# 9997      Sales               Male     White       Heterosexual
# 9998    Finance  Prefer not to say     White       Heterosexual
# 9999      Sales             Female     White  Prefer not to say
#
#                   LGBTQ         Indigenous Disability  Age Mobile Number  \
# 0     Prefer not to say                 No        Yes   29  363 436 1096
# ...

# %%
selected_columns = selected_columns.rename(columns={'Full Name': 'name', 'Email': 'email','Mobile Number': 'mobile', 'Gender': 'gender','Ethnicity': 'ethnicity', 'Sexual_Orientation': 'sexualOrientation','LGBTQ': 'lgbtq', 'Indigenous': 'indigenous'})

# %%
selected_columns
# Out:
#        Division             gender ethnicity  sexualOrientation  \
# 0            IT        Transgender     White       Heterosexual
# 1     Marketing               Male     White       Heterosexual
# 2       Finance             Female     White       Heterosexual
# 3            HR               Male     White       Heterosexual
# 4            RD               Male     Asian       Heterosexual
# ...         ...                ...       ...                ...
# 9995         HR               Male     White       Heterosexual
# 9996      Sales               Male     White       Heterosexual
# 9997      Sales               Male     White       Heterosexual
# 9998    Finance  Prefer not to say     White       Heterosexual
# 9999      Sales             Female     White  Prefer not to say
#
#                   lgbtq         indigenous Disability  Age        mobile  \
# 0     Prefer not to say                 No        Yes   29  363 436 1096
# ...

# %%
selected_columns = selected_columns.rename(columns={'Division': 'department', 'Disability': 'disability','Age': 'age'})

# %%
selected_columns
# Out:
#      department             gender ethnicity  sexualOrientation  \
# 0            IT        Transgender     White       Heterosexual
# 1     Marketing               Male     White       Heterosexual
# 2       Finance             Female     White       Heterosexual
# 3            HR               Male     White       Heterosexual
# 4            RD               Male     Asian       Heterosexual
# ...         ...                ...       ...                ...
# 9995         HR               Male     White       Heterosexual
# 9996      Sales               Male     White       Heterosexual
# 9997      Sales               Male     White       Heterosexual
# 9998    Finance  Prefer not to say     White       Heterosexual
# 9999      Sales             Female     White  Prefer not to say
#
#                   lgbtq         indigenous disability  age        mobile  \
# 0     Prefer not to say                 No        Yes   29  363 436 1096
# ...

# %%
import numpy as np

positions = {
    'IT': ['software developer', 'IT consultant', 'network engineer', 'systems analyst', 'database administrator', 'cybersecurity specialist', 'cloud architect'],
    'Marketing': ['marketing manager', 'digital marketer', 'social media specialist', 'brand strategist', 'market researcher'],
    'Finance': ['financial analyst', 'accountant', 'financial controller', 'investment analyst', 'tax specialist'],
    'HR': ['HR manager', 'recruitment specialist', 'compensation and benefits analyst', 'training and development coordinator', 'employee relations consultant'],
    'RD': ['research scientist', 'R&D engineer', 'innovation manager', 'product development specialist', 'technology analyst'],
    'Sales': ['sales manager', 'account executive', 'business development representative', 'sales operations analyst', 'customer success manager'],
    'Operations': ['operations manager', 'supply chain analyst', 'logistics coordinator', 'process improvement specialist', 'quality assurance engineer']
}
selected_columns['position'] = selected_columns['department'].apply(lambda x: np.random.choice(positions[x]))

# %%
selected_columns
# Out:
#      department             gender ethnicity  sexualOrientation  \
# 0            IT        Transgender     White       Heterosexual
# 1     Marketing               Male     White       Heterosexual
# 2       Finance             Female     White       Heterosexual
# 3            HR               Male     White       Heterosexual
# 4            RD               Male     Asian       Heterosexual
# ...         ...                ...       ...                ...
# 9995         HR               Male     White       Heterosexual
# 9996      Sales               Male     White       Heterosexual
# 9997      Sales               Male     White       Heterosexual
# 9998    Finance  Prefer not to say     White       Heterosexual
# 9999      Sales             Female     White  Prefer not to say
#
#                   lgbtq         indigenous disability  age        mobile  \
# 0     Prefer not to say                 No        Yes   29  363 436 1096
# ...

# %%
selected_columns.to_csv('employee_final.csv', index=False)

# %%
selected_columns['department'] = selected_columns['department'].str.lower()

# %%
selected_columns
# Out:
#      department             gender ethnicity  sexualOrientation  \
# 0            it        Transgender     White       Heterosexual
# 1     marketing               Male     White       Heterosexual
# 2       finance             Female     White       Heterosexual
# 3            hr               Male     White       Heterosexual
# 4            rd               Male     Asian       Heterosexual
# ...         ...                ...       ...                ...
# 9995         hr               Male     White       Heterosexual
# 9996      sales               Male     White       Heterosexual
# 9997      sales               Male     White       Heterosexual
# 9998    finance  Prefer not to say     White       Heterosexual
# 9999      sales             Female     White  Prefer not to say
#
#                   lgbtq         indigenous disability  age        mobile  \
# 0     Prefer not to say                 No        Yes   29  363 436 1096
# ...
